# %%
import turtle
import pickle

t = turtle.Turtle()
t.shape("turtle")
t.forward(100)
t.left(90)
t.forward(100)
t.right(90)
t.forward(100)
t.right(90)
t.forward(100)
t.left(90)
t.forward(100)

turtle.mainloop()
turtle.bye()
# Out:
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# Cell In[3], line 17
#      14 t.forward(100)
#      16 turtle.mainloop()
# ---> 17 turtle.bye()
#
# File <string>:5, in bye()
#
# Terminator:
